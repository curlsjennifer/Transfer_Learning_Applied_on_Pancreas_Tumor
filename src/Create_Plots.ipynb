# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import collections
from data_loader.data_loader import get_patches, table_generate, exp_path
# Out:
# Using TensorFlow backend.

# %%
table = table_generate()

# %%
exp_1 = "inc_selected"
exp_2 = "source"
exp_3 = "trans_3_2"
exp_4 = "trans_3_2"
exp_5 = "inc_selected_66"
exp_6 = "inc_selected"
exp_name = "B1F1S1"
table.load_results(exp_1, target=True, inc=True, label=exp_1)
table.load_results(exp_2, target=True, inc=False, label=exp_2)
table.load_results(exp_3, target=True, inc=False, label="trans_3")
#table.load_results(exp_4, target=True, inc=False, label="trans_3")
#table.load_results(exp_5, target=True, inc=True, label=exp_5)
#table.load_results(exp_6, target=True, inc=True, label=exp_6)
table.plot_res(exp_name, patient=False, num=True, x_label='number of target data')

# %%
table.plot_res(exp_name, patient=True, num=True, x_label='number of fixed layers')

# %%
table.plot_res(exp_name, patient=False, num=False, x_label='index')

# %%
table.plot_res(exp_name, patient=True, num=False, x_label='index')
